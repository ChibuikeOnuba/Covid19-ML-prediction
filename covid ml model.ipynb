# %% [markdown]
# COVID 19 ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# overview of the dataset

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
covid = pd.read_csv("Covid Data.csv")
print('Shape of dataset: ', covid.shape)
covid.head()
# Out:
# Shape of dataset:  (1048575, 21)
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
# 2               2        2              2        2                     3    2
# 3               2        2              2        2                     7   97
# 4               2        2              2        2                     3   97
#
# [5 rows x 21 columns]

# %%
covid.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# std    1.191288e+01  1.690739e+01  4.751073e+01  5.424242e+00  5.132258e+00
# min    1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.000000e+00  3.000000e+01  2.000000e+00  2.000000e+00  2.000000e+00
# 50%    2.000000e+00  4.000000e+01  9.700000e+01  2.000000e+00  2.000000e+00
# 75%    2.000000e+00  5.300000e+01  9.700000e+01  2.000000e+00  2.000000e+00
# max    9.900000e+01  1.210000e+02  9.800000e+01  9.800000e+01  9.800000e+01
#
#              ASTHMA       INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# count  1.048575e+06  1.048575e+06  1.048575e+06   1.048575e+06
# mean   2.242626e+00  2.298132e+00  2.128989e+00   2.435143e+00
# std    5.114089e+00  5.462843e+00  5.236397e+00   6.646676e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%    2.000000e+00  2.000000e+00  2.000000e+00   2.000000e+00
# 50%    2.000000e+00  2.000000e+00  2.000000e+00   2.000000e+00
# 75%    2.000000e+00  2.000000e+00  2.000000e+00   2.000000e+00
# max    9.800000e+01  9.800000e+01  9.800000e+01   9.800000e+01
#
#        CARDIOVASCULAR       OBESITY  RENAL_CHRONIC       TOBACCO  \
# count    1.048575e+06  1.048575e+06   1.048575e+06  1.048575e+06
# mean     2.261810e+00  2.125176e+00   2.257180e+00  2.214333e+00
# std      5.194850e+00  5.175445e+00   5.135354e+00  5.323097e+00
# min      1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# 25%      2.000000e+00  2.000000e+00   2.000000e+00  2.000000e+00
# 50%      2.000000e+00  2.000000e+00   2.000000e+00  2.000000e+00
# 75%      2.000000e+00  2.000000e+00   2.000000e+00  2.000000e+00
# max      9.800000e+01  9.800000e+01   9.800000e+01  9.800000e+01
#
#        CLASIFFICATION_FINAL           ICU
# count          1.048575e+06  1.048575e+06
# mean           5.305653e+00  7.955397e+01
# std            1.881165e+00  3.682307e+01
# min            1.000000e+00  1.000000e+00
# 25%            3.000000e+00  9.700000e+01
# 50%            6.000000e+00  9.700000e+01
# 75%            7.000000e+00  9.700000e+01
# max            7.000000e+00  9.900000e+01

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
#  14  OTHER_DISEASE         1048575 non-null  int64
#  15  CARDIOVASCULAR        1048575 non-null  int64
#  16  OBESITY               1048575 non-null  int64
#  17  RENAL_CHRONIC         1048575 non-null  int64
#  18  TOBACCO               1048575 non-null  int64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   1048575 non-null  int64
# dtypes: int64(20), object(1)
# memory usage: 168.0+ MB

# %%
covid.isna().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
covid.duplicated().sum()
# Out:
# 812049

# %% [markdown]
# ### NUMBER OF UNIQUE VALUES BY COLUMNS

# %%
for i in covid.columns:
    print(i,'-', len(covid[i].unique()))
# Out:
# USMER - 2
# MEDICAL_UNIT - 13
# SEX - 2
# PATIENT_TYPE - 2
# DATE_DIED - 401
# INTUBED - 4
# PNEUMONIA - 3
# AGE - 121
# PREGNANT - 4
# DIABETES - 3
# COPD - 3
# ASTHMA - 3
# INMSUPR - 3
# HIPERTENSION - 3
# OTHER_DISEASE - 3
# CARDIOVASCULAR - 3
# OBESITY - 3
# RENAL_CHRONIC - 3
# TOBACCO - 3
# CLASIFFICATION_FINAL - 7
# ICU - 4

# %% [markdown]
# Our primary analysis on the datser shows that the dataset contains no missing values and 812,049 duplicated values.
# But recall that the 'about dataset' shows that values 97 and 99 are missing values

# %%
covid.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %% [markdown]
# # Abot The Dataset
# #### This dataset contains an enormous number of anonymized patient-related information including pre-conditions. The raw dataset consists of 21 unique features and 1,048,576 unique patients. In the Boolean features, 1 means "yes" and 2 means "no". values as 97 and 99 are missing data.
#
# * sex: female or male
# * age: of the patient.
# * classification: covid test findings. Values 1-3 mean that the patient was diagnosed with covid in different
# * degrees. 4 or higher means that the patient is not a carrier of covid or that the test is inconclusive.
# * patient type: hospitalized or not hospitalized.
# * pneumonia: whether the patient already have air sacs inflammation or not.
# * pregnancy: whether the patient is pregnant or not.
# * diabetes: whether the patient has diabetes or not.
# * copd: Indicates whether the patient has Chronic obstructive pulmonary disease or not.
# * asthma: whether the patient has asthma or not.
# * inmsupr: whether the patient is immunosuppressed or not.
# * hypertension: whether the patient has hypertension or not.
# * cardiovascular: whether the patient has heart or blood vessels related disease.
# * renal chronic: whether the patient has chronic renal disease or not.
# * other disease: whether the patient has other disease or not.
# * obesity: whether the patient is obese or not.
# * tobacco: whether the patient is a tobacco user.
# * usmr: Indicates whether the patient treated medical units of the first, second or third level.
# * medical unit: type of institution of the National Health System that provided the care.
# * intubed: whether the patient was connected to the ventilator.
# * icu: Indicates whether the patient had been admitted to an Intensive Care Unit.
# * death: indicates whether the patient died or recovered.

# %% [markdown]
# For easier comprehension, the columns will be selected and replaced with 'Yes' for 1 and 'No' for 2 (asper the description)

# %%
col_vals = ['PATIENT_TYPE', 'INTUBED', 'PNEUMONIA', 'PREGNANT', 'DIABETES', 'COPD', 
            'ASTHMA', 'INMSUPR', 'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 
            'OBESITY', 'RENAL_CHRONIC', 'TOBACCO', 'ICU']

for i in col_vals:
    covid[i] = covid[i].replace(1, 'Yes').replace(2, 'No')

# %% [markdown]
# some columns are still having 3 or more unique values(Yes, No, 97, 99).
#
# Here, a plot is created to visualize the amount of unique values in the columns

# %%
def view(cols):
    sns.countplot(covid[cols])

# %%
i=0
plt.figure(figsize=(27, 17), dpi=100)
for col in col_vals:
    
    plt.subplot(3, 5, i+1)
    
    view(col)
    i=i+1

plt.show()

# %% [markdown]
# Notice that the ICU and INTUBED columns have very high number of null values (view below)

# %%
covid['INTUBED'].value_counts().plot(kind='pie', autopct='%.2f')
plt.title('INTUBED BY UNIQUE VALUES', color='blue')
# Out:
# Text(0.5, 1.0, 'INTUBED BY UNIQUE VALUES')

# %%
covid['ICU'].value_counts().plot(kind='pie', autopct = '%.2f')
plt.title('ICU BY UNIQUE VALUES', color='blue')
# Out:
# Text(0.5, 1.0, 'ICU BY UNIQUE VALUES')

# %% [markdown]
# We see that over 80% of the column values are missing value.
#
# It will be inappropriate to fill the missing values because it will create decrease the integrity of the dataset greatly.
# Hence the columns are dropped

# %%
covid.drop(columns=['ICU', 'INTUBED'], inplace=True)

# %% [markdown]
# Also observe that the sex column wasn not specified (male or female), but this is can figured out.
#
# The visualization below shows that there is a relationship between the 'PREGNANT' and the 'SEX' columns

# %%
plt.figure(figsize=(4, 4))
sns.countplot(covid['SEX'], hue=covid['PREGNANT'])
plt.legend(loc='best')
plt.title('count of Pregnancy by sex', color='blue')
# Out:
# Text(0.5, 1.0, 'count of Pregnancy by sex')

# %% [markdown]
# From the image, we can see that all the null value(97) falls under sex-2. And since males do not give birth, their values in the 'pregnant' column will be null, hence sex 2 is the male sex

# %%
covid['SEX'] = covid['SEX'].replace(1, 'Female').replace(2, 'Male')
covid['PREGNANT'].replace(97, 'No', inplace=True)

# %%
for i in covid.columns:
    print(i,'-', len(covid[i].unique()))
# Out:
# USMER - 2
# MEDICAL_UNIT - 13
# SEX - 2
# PATIENT_TYPE - 2
# DATE_DIED - 401
# PNEUMONIA - 3
# AGE - 121
# PREGNANT - 3
# DIABETES - 3
# COPD - 3
# ASTHMA - 3
# INMSUPR - 3
# HIPERTENSION - 3
# OTHER_DISEASE - 3
# CARDIOVASCULAR - 3
# OBESITY - 3
# RENAL_CHRONIC - 3
# TOBACCO - 3
# CLASIFFICATION_FINAL - 7

# %% [markdown]
# Next we drop the empty values for selected columns

# %%
cols = ['PNEUMONIA','PREGNANT', 'DIABETES', 'COPD', 
        'ASTHMA', 'INMSUPR', 'HIPERTENSION','OTHER_DISEASE', 
        'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC','TOBACCO']
for col in cols:
    covid = covid[(covid[col]=='Yes') | (covid[col]=='No')]

# %%
covid
# Out:
#          USMER  MEDICAL_UNIT     SEX PATIENT_TYPE   DATE_DIED PNEUMONIA  AGE  \
# 0            2             1  Female          Yes  03/05/2020       Yes   65
# 1            2             1    Male          Yes  03/06/2020       Yes   72
# 2            2             1    Male           No  09/06/2020        No   55
# 3            2             1  Female          Yes  12/06/2020        No   53
# 4            2             1    Male          Yes  21/06/2020        No   68
# ...        ...           ...     ...          ...         ...       ...  ...
# 1048570      2            13    Male          Yes  9999-99-99        No   40
# 1048571      1            13    Male           No  9999-99-99        No   51
# 1048572      2            13    Male          Yes  9999-99-99        No   55
# 1048573      2            13    Male          Yes  9999-99-99        No   28
# 1048574      2            13    Male          Yes  9999-99-99        No   52
#
#         PREGNANT DIABETES COPD ASTHMA INMSUPR HIPERTENSION OTHER_DISEASE  \
# 0             No       No   No     No      No          Yes            No
# 1             No       No   No     No      No          Yes            No
# 2             No      Yes   No     No      No           No            No
# 3             No       No   No     No      No           No            No
# 4             No      Yes   No     No      No          Yes            No
# ...          ...      ...  ...    ...     ...          ...           ...
# 1048570       No       No   No     No      No           No            No
# 1048571       No       No   No     No      No          Yes            No
# 1048572       No       No   No     No      No           No            No
# 1048573       No       No   No     No      No           No            No
# 1048574       No       No   No     No      No           No            No
#
#         CARDIOVASCULAR OBESITY RENAL_CHRONIC TOBACCO  CLASIFFICATION_FINAL
# 0                   No      No            No      No                     3
# 1                   No     Yes           Yes      No                     5
# 2                   No      No            No      No                     3
# 3                   No      No            No      No                     7
# 4                   No      No            No      No                     3
# ...                ...     ...           ...     ...                   ...
# 1048570             No      No            No      No                     7
# 1048571             No      No            No      No                     7
# 1048572             No      No            No      No                     7
# 1048573             No      No            No      No                     7
# 1048574             No      No            No      No                     7
#
# [1021977 rows x 19 columns]

# %% [markdown]
# Next, create the target column 'DEAD' using the 'DATE_DIED' column
#
# Then we drop the 'DATE_DIED' column

# %%
covid['DEAD'] = ['No' if each == '9999-99-99' else 'Yes' for each in covid['DATE_DIED']]
covid.drop(columns='DATE_DIED', axis=1, inplace=True)

# %%
covid
# Out:
#          USMER  MEDICAL_UNIT     SEX PATIENT_TYPE PNEUMONIA  AGE PREGNANT  \
# 0            2             1  Female          Yes       Yes   65       No
# 1            2             1    Male          Yes       Yes   72       No
# 2            2             1    Male           No        No   55       No
# 3            2             1  Female          Yes        No   53       No
# 4            2             1    Male          Yes        No   68       No
# ...        ...           ...     ...          ...       ...  ...      ...
# 1048570      2            13    Male          Yes        No   40       No
# 1048571      1            13    Male           No        No   51       No
# 1048572      2            13    Male          Yes        No   55       No
# 1048573      2            13    Male          Yes        No   28       No
# 1048574      2            13    Male          Yes        No   52       No
#
#         DIABETES COPD ASTHMA INMSUPR HIPERTENSION OTHER_DISEASE  \
# 0             No   No     No      No          Yes            No
# 1             No   No     No      No          Yes            No
# 2            Yes   No     No      No           No            No
# 3             No   No     No      No           No            No
# 4            Yes   No     No      No          Yes            No
# ...          ...  ...    ...     ...          ...           ...
# 1048570       No   No     No      No           No            No
# 1048571       No   No     No      No          Yes            No
# 1048572       No   No     No      No           No            No
# 1048573       No   No     No      No           No            No
# 1048574       No   No     No      No           No            No
#
#         CARDIOVASCULAR OBESITY RENAL_CHRONIC TOBACCO  CLASIFFICATION_FINAL  \
# 0                   No      No            No      No                     3
# 1                   No     Yes           Yes      No                     5
# 2                   No      No            No      No                     3
# 3                   No      No            No      No                     7
# 4                   No      No            No      No                     3
# ...                ...     ...           ...     ...                   ...
# 1048570             No      No            No      No                     7
# 1048571             No      No            No      No                     7
# 1048572             No      No            No      No                     7
# 1048573             No      No            No      No                     7
# 1048574             No      No            No      No                     7
#
#         DEAD
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
# ...      ...
# 1048570   No
# 1048571   No
# 1048572   No
# 1048573   No
# 1048574   No
#
# [1021977 rows x 19 columns]

# %% [markdown]
# ### VISUALISATION

# %% [markdown]
#  The visualization comprises the univariate analysis and bivariate analysis

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
sns.histplot(covid['AGE'])
plt.title('Age Count', color='blue')
# Out:
# Text(0.5, 1.0, 'Age Count')

# %% [markdown]
# The distribution shows that most patients fall between the ages of 20 and 60

# %%
ax = sns.countplot(covid['SEX'])
plt.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '510041'), Text(0, 0, '511936')]

# %%
plt.figure(figsize=(6,4))
sns.boxplot(covid['DEAD'], covid['AGE'])
plt.title('AGE AGAINST DEAD')
# Out:
# Text(0.5, 1.0, 'AGE AGAINST DEAD')

# %% [markdown]
# * Older patients are more likely to die of COVID19 than younger patients

# %%
plt.figure(figsize=(5,3))
sns.boxplot(covid['SEX'], covid['AGE'])
# Out:
# <AxesSubplot:xlabel='SEX', ylabel='AGE'>

# %% [markdown]
# * There is no much difference among sexes in terms of average age of patients

# %%
ax = sns.countplot(covid['DEAD'], hue=covid['SEX'], color='red')
plt.bar_label(ax.containers[0])
plt.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '48087'), Text(0, 0, '463849')]

# %% [markdown]
# * More males died from covid19 than females

# %%
ax = sns.countplot(covid['OBESITY'], color='yellow')
plt.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '865383'), Text(0, 0, '156594')]

# %%
sns.boxplot(covid['DEAD'], covid['AGE'], hue=covid['SEX'])
plt.title('Average age distribution of Death by Sex')
# Out:
# Text(0.5, 1.0, 'Average age distribution of Death by Sex')

# %%
ax = sns.countplot(data=covid, x='CARDIOVASCULAR')
plt.bar_label(ax.containers[0])
plt.title('COUNT OF CARDIOVASCULAR PATIENTS')
# Out:
# Text(0.5, 1.0, 'COUNT OF CARDIOVASCULAR PATIENTS')

# %% [markdown]
# * Only very few of the patients have cardiovascular diseases

# %% [markdown]
# ## FEATURE ENGINEERING

# %% [markdown]
# ##### ENCODING THE CATEGORICAL COLUMNS

# %%
cat_cols = ['SEX', 'PATIENT_TYPE', 'PNEUMONIA',
       'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION',
       'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC',
       'TOBACCO']

# %% [markdown]
# The categorical columns is encoded using the onehotencoder rather than labelencoding because the values of the columns are not hierarchical in nature

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onehot = OneHotEncoder()

# %%
winn = onehot.fit_transform(covid['SEX'].values.reshape(-1, 1)).copy

# %%
onehot = OneHotEncoder()
for i in cat_cols:
    covid[i] = onehot.fit_transform(covid[i].values.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [35], line 3
#       1 onehot = OneHotEncoder()
#       2 for i in cat_cols:
# ----> 3     covid[i] = onehot.fit_transform(covid[i].values.reshape(-1,1))
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:556, in require_length_match(data, index)
#     552 def require_length_match(data, index: Index):
#     553     """
#     554     Check the length of data matches the length of the index.
#     555     """
# --> 556     if len(data) != len(index):
#     557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#     560             "does not match length of index "
#     561             f"({len(index)})"
#     562         )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_base.py:345, in spmatrix.__len__(self)
#     344 def __len__(self):
# --> 345     raise TypeError("sparse matrix length is ambiguous; use getnnz()"
#     346                     " or shape[0]")
#
# TypeError: sparse matrix length is ambiguous; use getnnz() or shape[0]

# %% [markdown]
# There are too many columns in the dataset (19). Working with too many features for prediction can reduce the accuracy of the model. Hence columns with little or no correlation with the target columns will be dropped
